# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats
from datetime import datetime
from sqlalchemy import create_engine

# %%
# read in dow file
file = "dow_copy.csv"

dow_df = pd.read_csv(file)
dow_df.head()
# Out:
#         Date      Price       Open       High        Low     Vol. Change %
# 0  12-Mar-12  12,959.71  12,920.58  12,976.36  12,919.98  100.00M    0.29%
# 1   9-Jul-12  12,736.29  12,772.02  12,772.02  12,686.57  100.15M   -0.28%
# 2  27-Dec-12  13,096.31  13,114.97  13,141.74  12,964.08  100.16M   -0.14%
# 3  21-Jul-15  17,919.29  18,096.67  18,096.67  17,868.34  100.17M   -1.00%
# 4  20-Apr-16  18,096.27  18,059.49  18,167.63  18,031.21  100.21M    0.24%

# %%
# convert header UC to LC
dow_df.columns = dow_df.columns.str.lower()
dow_df
# Out:
#            date      price       open       high        low     vol. change %
# 0     12-Mar-12  12,959.71  12,920.58  12,976.36  12,919.98  100.00M    0.29%
# 1      9-Jul-12  12,736.29  12,772.02  12,772.02  12,686.57  100.15M   -0.28%
# 2     27-Dec-12  13,096.31  13,114.97  13,141.74  12,964.08  100.16M   -0.14%
# 3     21-Jul-15  17,919.29  18,096.67  18,096.67  17,868.34  100.17M   -1.00%
# 4     20-Apr-16  18,096.27  18,059.49  18,167.63  18,031.21  100.21M    0.24%
# ...         ...        ...        ...        ...        ...      ...      ...
# 2419  16-Sep-15  16,739.95  16,599.51  16,755.98  16,593.90   99.62M    0.84%
# 2420   7-Dec-15  17,730.51  17,845.49  17,845.49  17,639.25   99.67M   -0.66%
# 2421  12-Sep-13  15,300.64  15,327.14  15,345.32  15,283.26   99.76M   -0.17%
# 2422   8-Feb-13  13,992.97  13,944.05  14,022.62  13,944.05   99.86M    0.35%
# 2423   4-Nov-15  17,867.58  17,929.58  17,964.12  17,828.83   99.89M   -0.28%
#
# [2424 rows x 7 columns]

# %%
# change header names where needed
dow_df = dow_df.rename(columns={'vol.': 'vol_m', 
                                'change %':'chng',
                                'date': 'dt'})
dow_df.head()
# Out:
#           dt      price       open       high        low    vol_m    chng
# 0  12-Mar-12  12,959.71  12,920.58  12,976.36  12,919.98  100.00M   0.29%
# 1   9-Jul-12  12,736.29  12,772.02  12,772.02  12,686.57  100.15M  -0.28%
# 2  27-Dec-12  13,096.31  13,114.97  13,141.74  12,964.08  100.16M  -0.14%
# 3  21-Jul-15  17,919.29  18,096.67  18,096.67  17,868.34  100.17M  -1.00%
# 4  20-Apr-16  18,096.27  18,059.49  18,167.63  18,031.21  100.21M   0.24%

# %%
# convert dates to pd datetime
dow_df['dt']= pd.to_datetime(dow_df["dt"])
dow_df.head()
# Out:
#           dt      price       open       high        low    vol_m    chng
# 0 2012-03-12  12,959.71  12,920.58  12,976.36  12,919.98  100.00M   0.29%
# 1 2012-07-09  12,736.29  12,772.02  12,772.02  12,686.57  100.15M  -0.28%
# 2 2012-12-27  13,096.31  13,114.97  13,141.74  12,964.08  100.16M  -0.14%
# 3 2015-07-21  17,919.29  18,096.67  18,096.67  17,868.34  100.17M  -1.00%
# 4 2016-04-20  18,096.27  18,059.49  18,167.63  18,031.21  100.21M   0.24%

# %%
dow_df.replace(',','', regex=True, inplace=True)
dow_df['vol_m'].replace('M','', regex=True, inplace=True)
dow_df.replace('%','', regex=True, inplace=True)

# %%
dow_df['price'] = dow_df['price'].astype(float)
dow_df['open'] = dow_df['open'].astype(float)
dow_df['high'] = dow_df['high'].astype(float)
dow_df['low'] = dow_df['low'].astype(float)
dow_df['vol_m'] = dow_df['vol_m'].astype(float)
dow_df['chng'] = dow_df['chng'].astype(float)
dow_df.head()
# Out:
#           dt     price      open      high       low   vol_m  chng
# 0 2012-03-12  12959.71  12920.58  12976.36  12919.98  100.00  0.29
# 1 2012-07-09  12736.29  12772.02  12772.02  12686.57  100.15 -0.28
# 2 2012-12-27  13096.31  13114.97  13141.74  12964.08  100.16 -0.14
# 3 2015-07-21  17919.29  18096.67  18096.67  17868.34  100.17 -1.00
# 4 2016-04-20  18096.27  18059.49  18167.63  18031.21  100.21  0.24

# %%
# read in store file
file2 = "store_update.csv"

store_df = pd.read_csv(file2)
store_df.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2017-152156   8/11/2017  11/11/2017    Second Class    CG-12520
# 1       2  CA-2017-152156   8/11/2017  11/11/2017    Second Class    CG-12520
# 2       3  CA-2017-138688   12/6/2017  16/06/2017    Second Class    DV-13045
# 3       4  US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
# 4       5  US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City       State  \
# 0      Claire Gute   Consumer  United States        Henderson    Kentucky
# 1      Claire Gute   Consumer  United States        Henderson    Kentucky
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  California
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region       Product ID         Category Sub-Category  \
# 0      42420.0  South  FUR-BO-10001798        Furniture    Bookcases
# 1      42420.0  South  FUR-CH-10000454        Furniture       Chairs
# 2      90036.0   West  OFF-LA-10000240  Office Supplies       Labels
# 3      33311.0  South  FUR-TA-10000577        Furniture       Tables
# 4      33311.0  South  OFF-ST-10000760  Office Supplies      Storage
#
#                                         Product Name     Sales
# 0                  Bush Somerset Collection Bookcase  261.9600
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.9400
# 2  Self-Adhesive Address Labels for Typewriters b...   14.6200
# 3      Bretford CR4500 Series Slim Rectangular Table  957.5775
# 4                     Eldon Fold 'N Roll Cart System   22.3680

# %%
# convert header UC to LC
store_df.columns = store_df.columns.str.lower()
store_df
# Out:
#       row id        order id  order date   ship date       ship mode  \
# 0          1  CA-2017-152156   8/11/2017  11/11/2017    Second Class
# 1          2  CA-2017-152156   8/11/2017  11/11/2017    Second Class
# 2          3  CA-2017-138688   12/6/2017  16/06/2017    Second Class
# 3          4  US-2016-108966  11/10/2016  18/10/2016  Standard Class
# 4          5  US-2016-108966  11/10/2016  18/10/2016  Standard Class
# ...      ...             ...         ...         ...             ...
# 9795    9796  CA-2017-125920  05/21/2017  28/05/2017  Standard Class
# 9796    9797  CA-2016-128608   12/1/2016  17/01/2016  Standard Class
# 9797    9798  CA-2016-128608   12/1/2016  17/01/2016  Standard Class
# 9798    9799  CA-2016-128608   12/1/2016  17/01/2016  Standard Class
# 9799    9800  CA-2016-128608   12/1/2016  17/01/2016  Standard Class
#
#      customer id     customer name    segment        country             city  \
# 0       CG-12520       Claire Gute   Consumer  United States        Henderson
# 1       CG-12520       Claire Gute   Consumer  United States        Henderson
# 2       DV-13045   Darrin Van Huff  Corporate  United States      Los Angeles
# 3       SO-20335    Sean O'Donnell   Consumer  United States  Fort Lauderdale
# 4       SO-20335    Sean O'Donnell   Consumer  United States  Fort Lauderdale
# ...          ...               ...        ...            ...              ...
# 9795    SH-19975     Sally Hughsby  Corporate  United States          Chicago
# 9796    CS-12490  Cindy Schnelling  Corporate  United States           Toledo
# 9797    CS-12490  Cindy Schnelling  Corporate  United States           Toledo
# 9798    CS-12490  Cindy Schnelling  Corporate  United States           Toledo
# 9799    CS-12490  Cindy Schnelling  Corporate  United States           Toledo
#
#            state  postal code   region       product id         category  \
# 0       Kentucky      42420.0    South  FUR-BO-10001798        Furniture
# 1       Kentucky      42420.0    South  FUR-CH-10000454        Furniture
# 2     California      90036.0     West  OFF-LA-10000240  Office Supplies
# 3        Florida      33311.0    South  FUR-TA-10000577        Furniture
# 4        Florida      33311.0    South  OFF-ST-10000760  Office Supplies
# ...          ...          ...      ...              ...              ...
# 9795    Illinois      60610.0  Central  OFF-BI-10003429  Office Supplies
# 9796        Ohio      43615.0     East  OFF-AR-10001374  Office Supplies
# 9797        Ohio      43615.0     East  TEC-PH-10004977       Technology
# 9798        Ohio      43615.0     East  TEC-PH-10000912       Technology
# 9799        Ohio      43615.0     East  TEC-AC-10000487       Technology
#
#      sub-category                                       product name     sales
# 0       Bookcases                  Bush Somerset Collection Bookcase  261.9600
# 1          Chairs  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.9400
# 2          Labels  Self-Adhesive Address Labels for Typewriters b...   14.6200
# 3          Tables      Bretford CR4500 Series Slim Rectangular Table  957.5775
# 4         Storage                     Eldon Fold 'N Roll Cart System   22.3680
# ...           ...                                                ...       ...
# 9795      Binders  Cardinal HOLDit! Binder Insert Strips,Extra St...    3.7980
# 9796          Art           BIC Brite Liner Highlighters, Chisel Tip   10.3680
# 9797       Phones                                        GE 30524EE4  235.1880
# 9798       Phones           Anker 24W Portable Micro USB Car Charger   26.3760
# 9799  Accessories                SanDisk Cruzer 4 GB USB Flash Drive   10.3840
#
# [9800 rows x 18 columns]

# %%
# change header names where needed
store_df = store_df.rename(columns={'row id':'row_id',
                                    'order id':'order_id',
                                    'order date' :'order_date',
                                    'ship date':'ship_date',
                                    'ship mode': 'ship_mode',
                                    'customer id': 'customer_id',
                                    'customer name': 'customer_name',
                                    'postal code': 'postal_code',
                                    'product id': 'product_id',
                                    'sub-category': 'sub_category',
                                    'product name': 'product_name'})
store_df.head()
# Out:
#    row_id        order_id  order_date   ship_date       ship_mode customer_id  \
# 0       1  CA-2017-152156   8/11/2017  11/11/2017    Second Class    CG-12520
# 1       2  CA-2017-152156   8/11/2017  11/11/2017    Second Class    CG-12520
# 2       3  CA-2017-138688   12/6/2017  16/06/2017    Second Class    DV-13045
# 3       4  US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
# 4       5  US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
#
#      customer_name    segment        country             city       state  \
# 0      Claire Gute   Consumer  United States        Henderson    Kentucky
# 1      Claire Gute   Consumer  United States        Henderson    Kentucky
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  California
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
#
#    postal_code region       product_id         category sub_category  \
# 0      42420.0  South  FUR-BO-10001798        Furniture    Bookcases
# 1      42420.0  South  FUR-CH-10000454        Furniture       Chairs
# 2      90036.0   West  OFF-LA-10000240  Office Supplies       Labels
# 3      33311.0  South  FUR-TA-10000577        Furniture       Tables
# 4      33311.0  South  OFF-ST-10000760  Office Supplies      Storage
#
#                                         product_name     sales
# 0                  Bush Somerset Collection Bookcase  261.9600
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.9400
# 2  Self-Adhesive Address Labels for Typewriters b...   14.6200
# 3      Bretford CR4500 Series Slim Rectangular Table  957.5775
# 4                     Eldon Fold 'N Roll Cart System   22.3680

# %%
store_df.columns
# Out:
# Index(['row_id', 'order_id', 'order_date', 'ship_date', 'ship_mode',
#        'customer_id', 'customer_name', 'segment', 'country', 'city', 'state',
#        'postal_code', 'region', 'product_id', 'category', 'sub_category',
#        'product_name', 'sales'],
#       dtype='object')

# %%
store_df=store_df[['order_id', 'order_date', 
                 'city', 'state','postal_code', 'region', 'product_id', 'category', 'sub_category','product_name', 'sales']]
store_df.head()
# Out:
#          order_id order_date             city       state  postal_code region  \
# 0  CA-2017-152156 2017-08-11        Henderson    Kentucky      42420.0  South
# 1  CA-2017-152156 2017-08-11        Henderson    Kentucky      42420.0  South
# 2  CA-2017-138688 2017-12-06      Los Angeles  California      90036.0   West
# 3  US-2016-108966 2016-11-10  Fort Lauderdale     Florida      33311.0  South
# 4  US-2016-108966 2016-11-10  Fort Lauderdale     Florida      33311.0  South
#
#         product_id         category sub_category  \
# 0  FUR-BO-10001798        Furniture    Bookcases
# 1  FUR-CH-10000454        Furniture       Chairs
# 2  OFF-LA-10000240  Office Supplies       Labels
# 3  FUR-TA-10000577        Furniture       Tables
# 4  OFF-ST-10000760  Office Supplies      Storage
#
#                                         product_name     sales
# 0                  Bush Somerset Collection Bookcase  261.9600
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.9400
# 2  Self-Adhesive Address Labels for Typewriters b...   14.6200
# 3      Bretford CR4500 Series Slim Rectangular Table  957.5775
# 4                     Eldon Fold 'N Roll Cart System   22.3680

# %%
# 0     South  FUR-BO-10001798        Furniture    Bookcases
# 1     South  FUR-CH-10000454        Furniture       Chairs
# 2      West  OFF-LA-10000240  Office Supplies       Labels
# 3     South  FUR-TA-10000577        Furniture       Tables
# 4     South  OFF-ST-10000760  Office Supplies      Storage
# 5      West  FUR-FU-10001487        Furniture  Furnishings
# 6      West  OFF-AR-10002833  Office Supplies          Art
# 7      West  TEC-PH-10002275       Technology       Phones
# 8      West  OFF-BI-10003910  Office Supplies      Binders
# 9      West  OFF-AP-10002892  Office Supplies   Appliances
# 10     West  FUR-TA-10001539        Furniture       Tables
# 11     West  TEC-PH-10002033       Technology       Phones
# 12    South  OFF-PA-10002365  Office Supplies        Paper
# 13     West  OFF-BI-10003656  Office Supplies      Binders
# 14  Central  OFF-AP-10002311  Office Supplies   Appliances
# 15  Central  OFF-BI-10000756  Office Supplies      Binders
# 16  Central  OFF-ST-10004186  Office Supplies      Storage
# 17     West  OFF-ST-10000107  Office Supplies      Storage
# 18     West  OFF-AR-10003056  Office Supplies          Art
# 19     West  TEC-PH-10001949       Technology       Phones
# 20     West  OFF-BI-10002215  Office Supplies      Binders
# 21  Central  OFF-AR-10000246  Office Supplies          Art
# 22  Central  OFF-AP-10001492  Office Supplies   Appliances
# 23     East  FUR-CH-10002774        Furniture       Chairs
# 24     West  FUR-TA-10000577        Furniture       Tables
# 25     West  OFF-BI-10001634  Office Supplies      Binders
# 26     West  TEC-AC-10003027       Technology  Accessories
# 27     East  FUR-BO-10004834        Furniture    Bookcases
# 28     East  OFF-BI-10000474  Office Supplies      Binders
# 29     East  FUR-FU-10004848        Furniture  Furnishings
# 30     East  OFF-EN-10001509  Office Supplies    Envelopes
# 31     East  OFF-AR-10004042  Office Supplies          Art
# 32     East  OFF-BI-10001525  Office Supplies      Binders
# 33     East  OFF-AR-10001683  Office Supplies          Art
# 34  Central  OFF-PA-10000249  Office Supplies        Paper
# 35  Central  TEC-PH-10004977       Technology       Phones
# 36  Central  FUR-FU-10003664        Furniture  Furnishings
# 37  Central  OFF-EN-10002986  Office Supplies    Envelopes
# 38  Central  FUR-BO-10002545        Furniture    Bookcases
# 39  Central  FUR-CH-10004218        Furniture       Chairs
# 40  Central  TEC-PH-10000486       Technology       Phones
# 41  Central  TEC-PH-10004093       Technology       Phones
# 42     West  OFF-ST-10003479  Office Supplies      Storage
# 43    South  OFF-ST-10003282  Office Supplies      Storage
# 44  Central  TEC-AC-10000171       Technology  Accessories
# 45  Central  OFF-BI-10003291  Office Supplies      Binders
# 46  Central  OFF-ST-10001713  Office Supplies      Storage
# 47     East  TEC-AC-10002167       Technology  Accessories
# 48     East  TEC-PH-10003988       Technology       Phones
# 49  Central  OFF-BI-10004410  Office Supplies      Binders
#
#                                          product_name      sales
# 0                   Bush Somerset Collection Bookcase   261.9600
# 1   Hon Deluxe Fabric Upholstered Stacking Chairs,...   731.9400
# 2   Self-Adhesive Address Labels for Typewriters b...    14.6200
# 3       Bretford CR4500 Series Slim Rectangular Table   957.5775
# 4                      Eldon Fold 'N Roll Cart System    22.3680
# 5   Eldon Expressions Wood and Plastic Desk Access...    48.8600
# 6                                          Newell 322     7.2800
# 7                      Mitel 5320 IP Phone VoIP phone   907.1520
# 8   DXL Angle-View Binders with Locking Rings by S...    18.5040
# 9                    Belkin F5C206VTEL 6 Outlet Surge   114.9000
# 10           Chromcraft Rectangular Conference Tables  1706.1840
# 11      Konftel 250 Conference phone - Charcoal black   911.4240
# 12                                         Xerox 1967    15.5520
# 13        Fellowes PB200 Plastic Comb Binding Machine   407.9760
# 14  Holmes Replacement Filter for HEPA Air Cleaner...    68.8100
# 15   Storex DuraTech Recycled Plastic Frosted Binders     2.5440
# 16  Stur-D-Stor Shelving, Vertical 5-Shelf: 72"H x...   665.8800
# 17                         Fellowes Super Stor/Drawer    55.5000
# 18                                         Newell 341     8.5600
# 19                            Cisco SPA 501G IP Phone   213.4800
# 20        Wilson Jones Hanging View Binder, White, 1"    22.7200
# 21                                         Newell 318    19.4600
# 22        Acco Six-Outlet Power Strip, 4' Cord Length    60.3400
# 23                 Global Deluxe Stacking Chair, Gray    71.3720
# 24      Bretford CR4500 Series Slim Rectangular Table  1044.6300
# 25                    Wilson Jones Active Use Binders    11.6480
# 26   Imation 8GB Mini TravelDrive USB 2.0 Flash Drive    90.5700
# 27  Riverside Palais Royal Lawyers Bookcase, Royal...  3083.4300
# 28  Avery Recycled Flexi-View Covers for Binding S...     9.6180
# 29  Howard Miller 13-3/4" Diameter Brushed Chrome ...   124.2000
# 30                          Poly String Tie Envelopes     3.2640
# 31  BOSTON Model 1800 Electric Pencil Sharpeners, ...    86.3040
# 32  Acco Pressboard Covers with Storage Hooks, 14 ...     6.8580
# 33                                     Lumber Crayons    15.7600
# 34                                  Easy-staple paper    29.4720
# 35                                        GE 30524EE4  1097.5440
# 36  Electrix Architect's Clamp-On Swing Arm Lamp, ...   190.9200
# 37  #10-4 1/8" x 9 1/2" Premium Diagonal Seam Enve...   113.3280
# 38  Atlantic Metals Mobile 3-Shelf Bookcases, Cust...   532.3992
# 39           Global Fabric Manager's Chair, Dark Gray   212.0580
# 40                    Plantronics HL10 Handset Lifter   371.1680
# 41                                 Panasonic Kx-TS550   147.1680
# 42   Eldon Base for stackable storage shelf, platinum    77.8800
# 43  Advantus 10-Drawer Portable Organizer, Chrome ...    95.6160
# 44  Verbatim 25 GB 6x Blu-ray Single Layer Recorda...    45.9800
# 45  Wilson Jones Leather-Like Binders with DublLoc...    17.4600
# 46  Gould Plastics 9-Pocket Panel Bin, 18-3/8w x 5...   211.9600
# 47  Imation 8gb Micro Traveldrive Usb 2.0 Flash Drive    45.0000
# 48  LF Elite 3D Dazzle Designer Hard Case Cover, L...    21.8000
# 49  C-Line Peel & Stick Add-On Filing Pockets, 8-3...    38.2200

# %%
# connect to pgAdmin
connection_String_format= '<user>:<passowrd>@<url>:<port>/<database_name>'
rds_connection_string = "postgres:Stuart2609!@localhost:5432/etl"
engine = create_engine(f'postgresql://{rds_connection_string}')

# %%
engine.table_names()
# Out:
# ['store', 'dow']

# %%
dow_df.to_sql(name='dow', con=engine, if_exists='append', index=False)

# %%
pd.read_sql_query('select * from dow', con=engine).tail()
# Out:
#         id          dt     price      open      high       low  vol_m  chng
# 2419  2420  2015-09-16  16739.95  16599.51  16755.98  16593.90  99.62  0.84
# 2420  2421  2015-12-07  17730.51  17845.49  17845.49  17639.25  99.67 -0.66
# 2421  2422  2013-09-12  15300.64  15327.14  15345.32  15283.26  99.76 -0.17
# 2422  2423  2013-02-08  13992.97  13944.05  14022.62  13944.05  99.86  0.35
# 2423  2424  2015-11-04  17867.58  17929.58  17964.12  17828.83  99.89 -0.28

# %%
store_df.to_sql(name='store', con=engine, if_exists='append', index=False)
